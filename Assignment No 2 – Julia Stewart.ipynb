# %% [markdown]
# # Lab Assignment 2 – Julia Stewart
# ## Student Number: **200017610**
# ### *https://github.com/JuliaStewart111/PY4SA23_Assignment.git*

# %% [markdown]
# ## **Task 1:** If... Else statement Divisible by Three

# %% [markdown]
# ##### This function tests whether a value (number) is divisible by three. **"YOUR VALUE is divisible by 3"** is printed if the value (n) is divisible by three. **"YOUR VALUE is not divisible by three"** is printed if the value (n) is not divisible by three. The statement is tested with the numeric value 6, as seen below. With the printed value replaced with the n value being tested number.

# %%
n = 6

if n % 3 == 0:
    print(n, "is divisible by three")

else:
    print(n, "is not divisible by three")
# Out:
# 6 is divisible by three

# %% [markdown]
# ## **Task 2:** If...Else statement that will test whether a type of fruit, represented as a text string,
#
# ##### This function will show a list of acceptable fruits (apple, orange, pear, kiwi, or strawberry). If the fruit is on the list, this will be seen **"YOUR FRUIT is acceptable."** If the fruit is not present then this will be seen **" YOUR FRUIT is not acceptable."** The fruit tested will replace the "YOUR FRUIT"

# %%
Fruit = [
    'apple',
    'orange',
    'blueberry',
    'strawberry',
    'Kiwi'
]

i= "Kiwi" 
if i in Fruit:
    print(i, "is acceptable")
else:
    print(i, "is not acceptable")
# Out:
# Kiwi is acceptable

# %% [markdown]
# ## **Task Three:** Function to calculate distance between two coordinates using haversine formula.

# %%
##T3: Create a function to calculate the distance between two coordinates using the haversine
##formula. Write the following formula where the input parameters are a pair of coordinates as two
##lists.
#two lists of coordinates 
from math import sin, cos, atan2, radians
A= [radians(55.9533), radians(3.1883)] 
B= [radians(57.1499), radians(2.0938)]

def functa(A,B):
    return sin(B[0] - A[0]/2)**2 + cos(A[0]) * cos(B[0]) * sin(B[1] - A[1]/2)**2
a = functa(A,B)
print("a=", functa(A,B))

def functc(a):
    return 2 * atan2(a**0.5, (1 - a)**0.5)
c= functc(a)
print("c =", functc(a))

R = 6371
Distance = R * c
print("Result: ", Distance)
# Out:
# a= 0.23763260565995395
# c = 1.0183927930031569
# Result:  6488.180484223112

# %% [markdown]
# ## Pandas and NumPy Part 2
# ### **Question 1**
# #### How many trees are of the Quercus or Acer genus?

# %%
## Import appropriate packages
import pandas as pd
import numpy as np
file = pd.read_csv('data\portland_park_trees.csv') ##add the required data set
file.head()
# Out:
#    fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# 0    1       426  2017/05/09    PSME  37.4      Fair       105.0        44.0
# 1    2       427  2017/05/09    PSME  32.5      Fair        94.0        49.0
# 2    3       428  2017/05/09    CRLA   9.7      Fair        23.0        28.0
# 3    4       429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 4    5       430  2017/05/09    PSME  33.2      Fair       102.0        43.0
#
#    CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# 0        57.0      staff  ...  Pseudotsuga       Douglas-fir
# 1        45.0      staff  ...  Pseudotsuga       Douglas-fir
# 2        27.0      staff  ...    Crataegus  Lavalle hawthorn
# 3        31.0      staff  ...      Quercus  northern red oak
# 4        44.0      staff  ...  Pseudotsuga       Douglas-fir
#
#               Genus_spec Functional Size Native Edible Nuisance  \
# 0  Pseudotsuga menziesii         CE    L    Yes    NaN      NaN
# ...

# %%
# Select the two required genus 
#Calculate number of trees in those genus
df = pd.read_csv('data\portland_park_trees.csv')
trees = ['Quercus', 'Acer']
df['Genus'].isin(trees).sum()
#5675 (total amount of trees within the Quercus and Acer category)
# Out:
# 5675

# %% [markdown]
# ### Question 2
# #### How many trees are of the Quercus or Acer genus and have a DBH larger than 50 inches?

# %%
df = pd.read_csv('data\portland_park_trees.csv')
QA = ['Quercus', 'Acer']
fifty_df = df.loc[(df.DBH >50)]
print("Number of Quercus and Acer trees with DBH > 50 is", fifty_df['Genus'].isin(QA).sum())
# Out:
# Number of Quercus and Acer trees with DBH > 50 is 124

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### Which genus has the highest mean DBH of the following genera: Quercus, Acer, or Fraxinus?

# %%
Atree = ['Acer']
Acermean = df["DBH"][df['Genus'].isin(Atree)].mean()
print ("Acer mean DBH:", Acermean, "inches")

Qtree = ['Quercus']
Quercusmean = df["DBH"][df['Genus'].isin(Qtree)].mean()
print ("Quercus mean DBH:", Quercusmean, "inches")

Ftree = ['Fraxinus']
Fraxinusmean = df["DBH"][df['Genus'].isin(Ftree)].mean()
print ("Fraxinus mean DBH:", Fraxinusmean, "inches")

Means = [Quercusmean, Acermean, Fraxinusmean]

if max(Means) == Quercusmean:
    print ("Quercusmean mean DBH is highest:",max(Means), "inches")
    
else:
    if max(Means) == Fraxinusmean:
        print ("Fraxinusmean mean DBH is highest:",max(Means))
    
    else:
        print ("Acermean DBH is highest:",max(means))
# Out:
# Acer mean DBH: 18.419085331846066 inches
# Quercus mean DBH: 23.56823839157492 inches
# Fraxinus mean DBH: 11.033609693877551 inches
# Quercusmean mean DBH is highest: 23.56823839157492 inches

# %% [markdown]
# ## Question 4

# %% [markdown]
# #### How many different species of trees are recorded in the Acer genus?

# %%
Acer_df = df.loc[(df['Genus'] == 'Acer')]
Acer_df['Species'].nunique()
print ("There are ", Acer_df['Species'].nunique(), "species in the Acer genus")
# Out:
# There are  20 species in the Acer genus

# %% [markdown]
# ## Question 5

# %% [markdown]
# #### Download data as Pandas

# %%
import pandas as pd #importing the required world cities csv file
import numpy as np
file = pd.read_csv('Data/world_cities.csv')
file.head()
# Out:
#                  city    country    pop    lat    lon  capital
# 0  'Abasan al-Jadidah  Palestine   5629  31.31  34.34        0
# 1  'Abasan al-Kabirah  Palestine  18999  31.32  34.35        0
# 2        'Abdul Hakim   Pakistan  47788  30.55  72.11        0
# 3  'Abdullah-as-Salam     Kuwait  21817  29.36  47.98        0
# 4               'Abud  Palestine   2456  32.03  35.07        0

# %% [markdown]
# ## Question 5: Part 1

# %%
# Add column using np.where()
data = pd.read_csv('Data/world_cities.csv')
data['pop_M'] = (data['pop'] / 1000000)
#removing the orignial 'pop column'
del data['pop']
data
# Out:
#                      city       country    lat    lon  capital     pop_M
# 0      'Abasan al-Jadidah     Palestine  31.31  34.34        0  0.005629
# 1      'Abasan al-Kabirah     Palestine  31.32  34.35        0  0.018999
# 2            'Abdul Hakim      Pakistan  30.55  72.11        0  0.047788
# 3      'Abdullah-as-Salam        Kuwait  29.36  47.98        0  0.021817
# 4                   'Abud     Palestine  32.03  35.07        0  0.002456
# ...                   ...           ...    ...    ...      ...       ...
# 43640           az-Zubayr          Iraq  30.39  47.71        0  0.124611
# 43641            az-Zulfi  Saudi Arabia  26.30  44.80        0  0.054070
# 43642       az-Zuwaytinah         Libya  30.95  20.12        0  0.021984
# 43643        s-Gravenhage   Netherlands  52.07   4.30        0  0.479525
# 43644     s-Hertogenbosch   Netherlands  51.68   5.30        0  0.135529
#
# [43645 rows x 6 columns]

# %% [markdown]
# #### Calculate a new column named "pop_M" (population in millions), by transforming the"pop" (population) column.

# %% [markdown]
# #### Importing required (World Cities csv file)

# %%
#import required data set: World citites csv file in pandas
cities_df = pd.DataFrame(data, columns=['city'])
print(cities_df)
# Out:
#                      city
# 0      'Abasan al-Jadidah
# 1      'Abasan al-Kabirah
# 2            'Abdul Hakim
# 3      'Abdullah-as-Salam
# 4                   'Abud
# ...                   ...
# 43640           az-Zubayr
# 43641            az-Zulfi
# 43642       az-Zuwaytinah
# 43643        s-Gravenhage
# 43644     s-Hertogenbosch
#
# [43645 rows x 1 columns]

# %% [markdown]
# #### Selecting and Subsetting Cities

# %%
#selecting cities that begin with the the letter "J". 
cities_df = pd.DataFrame(data, columns=['city'])

contain_values = cities_df[cities_df['city'].str.startswith('J')]
print (contain_values)
# Out:
#                           city
# 15840                    Ja'ar
# 15841                    Jaala
# 15842                Jaamakula
# 15843               Jaanimoisa
# 15844                   Jaarja
# ...                        ...
# 16562                  Jwaneng
# 16563                  Jyderup
# 16564                 Jyllinge
# 16565                Jyvaskyla
# 16566  Jyvaskylan maalaiskunta
#
# [727 rows x 1 columns]

# %%
#select a city starting with letter J from the list above
#jaala [15841] selected
#subset a city starting with letter J
df.iloc[15841]
print(df.iloc[15841])
# Out:
# fid                                                       15842
# OBJECTID                                                 445971
# Inventory_                                           2018/10/18
# Species                                                    THPL
# DBH                                                        25.0
# Condition                                                  Fair
# TreeHeight                                                 50.0
# CrownWidth                                                 36.0
# CrownWid_1                                                 29.0
# CollectedB                                                staff
# Notes                                                       NaN
# CrownBaseH                                                  2.0
# GlobalID                 {3B0FDABD-78E0-4E43-AF7B-D28F4D914414}
# StaffRevie                                                  NaN
# created_us                                        ben.rushakoff
# ...

# %% [markdown]
# ## Question 5: Part 4

# %% [markdown]
# #### Subset the five biggest (i.e., largest population sizes) cities from the country where your selected city is

# %%
#find which country Jaala belongs to 
country_df = pd.DataFrame(data, columns=['city','country'])

contain_values = country_df[country_df['city'].str.contains('Jaala')]
print (contain_values)
# Out:
#         city  country
# 15841  Jaala  Finland

# %%
Finland_df = data[data['country'] == "Finland"]
print(Finland_df)
# Out:
#               city  country    lat    lon  capital     pop_M
# 150      Aanekoski  Finland  62.61  25.69        0  0.013358
# 427          Aetsa  Finland  61.28  22.68        0  0.004912
# 608         Ahtari  Finland  62.57  24.10        0  0.006764
# 801       Alaharma  Finland  63.23  22.85        0  0.004908
# 803       Alajarvi  Finland  63.00  23.82        0  0.008686
# ...            ...      ...    ...    ...      ...       ...
# 42393  Ylikiiminki  Finland  65.08  26.25        0  0.003409
# 42394     Ylistaro  Finland  62.95  22.52        0  0.005572
# 42395    Ylitornio  Finland  66.30  23.67        0  0.005030
# 42396    Ylivieska  Finland  64.08  24.53        0  0.013154
# 42397     Ylojarvi  Finland  61.55  23.60        0  0.022438
#
# [430 rows x 6 columns]

# %%
#subset the five biggest cities according to population
# find maximum values of a list of columns
maxValue = Finland_df.nlargest(n=5, columns='pop_M')
print(maxValue)
# Out:
#            city  country    lat    lon  capital     pop_M
# 14194  Helsinki  Finland  60.17  24.94        1  0.558341
# 10950     Espoo  Finland  60.21  24.66        0  0.232293
# 37255   Tampere  Finland  61.52  23.76        0  0.203606
# 40066    Vantaa  Finland  60.29  25.04        0  0.190622
# 39227     Turku  Finland  60.45  22.25        0  0.176425

# %%
#this is the final out put for Q5
Finland_df.nlargest(n=5, columns='pop_M')
# Out:
#            city  country    lat    lon  capital     pop_M
# 14194  Helsinki  Finland  60.17  24.94        1  0.558341
# 10950     Espoo  Finland  60.21  24.66        0  0.232293
# 37255   Tampere  Finland  61.52  23.76        0  0.203606
# 40066    Vantaa  Finland  60.29  25.04        0  0.190622
# 39227     Turku  Finland  60.45  22.25        0  0.176425

# %%
FinlandTop5 = Finland_df.nlargest(n=5, columns='pop_M')
print(FinlandTop5)
# Out:
#            city  country    lat    lon  capital     pop_M
# 14194  Helsinki  Finland  60.17  24.94        1  0.558341
# 10950     Espoo  Finland  60.21  24.66        0  0.232293
# 37255   Tampere  Finland  61.52  23.76        0  0.203606
# 40066    Vantaa  Finland  60.29  25.04        0  0.190622
# 39227     Turku  Finland  60.45  22.25        0  0.176425

# %% [markdown]
# ## Python Data Visualization

# %% [markdown]
# #### Graph 1:

# %% [markdown]
# #### Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis and tree height mapped to the y-axis (Hint: You will need to use the “Genus”, “DBH”, and “TreeHeight” attributes.)

# %%
#data set

# %%
# Import seaborn
import seaborn as sns

# %%
#importing data set
df = pd.read_csv('data\portland_park_trees.csv')
df
# Out:
#          fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  \
# 0          1       426  2017/05/09    PSME  37.4      Fair       105.0
# 1          2       427  2017/05/09    PSME  32.5      Fair        94.0
# 2          3       428  2017/05/09    CRLA   9.7      Fair        23.0
# 3          4       429  2017/05/09    QURU  10.3      Poor        28.0
# 4          5       430  2017/05/09    PSME  33.2      Fair       102.0
# ...      ...       ...         ...     ...   ...       ...         ...
# 25529  25530    726046  2018/08/16    QURU  31.6      Fair        74.0
# 25530  25531    726443  2019/10/11    PSME   0.4      Good         8.0
# 25531  25532    726444  2019/10/11    MEGL  26.3      Fair        79.0
# 25532  25533    726445  2019/10/11    PCSI   8.8      Fair        43.0
# 25533  25534    726446  2019/10/11    COKO   2.0      Good        18.0
#
#        CrownWidth  CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# ...

# %%
#selecting only Ulmus genus
Ulmus_df = df[df['Genus'] == "Ulmus"]
print(Ulmus_df)
# Out:
#          fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  \
# 57        58       483  2017/05/19    ULPU  40.5      Poor        75.0
# 58        59       484  2017/05/19    ULPU  48.5      Fair        96.0
# 59        60       485  2017/05/19    ULPU  34.0      Fair        74.0
# 60        61       486  2017/05/19    ULPU  35.0      Fair        60.0
# 63        64       489  2017/05/19    ULPU  35.5      Poor        79.0
# ...      ...       ...         ...     ...   ...       ...         ...
# 24765  24766    707646  2019/10/02    ULAM   7.9      Fair        21.0
# 24767  24768    707648  2019/10/02    ULAM   3.5      Fair        18.0
# 24768  24769    707649  2019/10/02    ULAM   3.7      Fair        30.0
# 24776  24777    708049  2019/10/02    ULAM   3.5      Fair        17.0
# 24791  24792    708453  2019/10/02    ULAM   5.9      Fair        30.0
#
#        CrownWidth  CrownWid_1 CollectedB  ...  Genus    Common_nam  \
# ...

# %%
#producing a scatter plot comparing DBH and Tree Heigh of the Ulmus Species
sns.relplot(x="DBH", y="TreeHeight", data=Ulmus_df)

# %%
#producing a a scatter plot in more depth
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # alias is plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 12]

fig, axs = plt.subplots(1, 1)
sns.scatterplot(ax=axs, x="DBH", y="TreeHeight", hue="Genus", data=Ulmus_df)
axs.set_title("DBH vs. TreeHeight", fontsize=20, color="#000000")
handles, labels = axs.get_legend_handles_labels()
axs.legend(handles=handles[1:], labels=labels[1:], title="Genus", title_fontsize=12) # Optional
axs.grid(True)
fig.patch.set_facecolor('#adb7c7')
plt.show(fig)

# %% [markdown]
# ## Graph 2

# %% [markdown]
# #### Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis, tree height mapped to the y-axis, and tree species mapped to hue (Hint: You will need to use the “Genus”, “Genus_spec”, “DBH”, and “TreeHeight” attributes.)

# %%
sns.relplot(x="DBH", y="TreeHeight", hue="Genus_spec", data=Ulmus_df)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # alias is plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 12]

fig, axs = plt.subplots(1, 1)
sns.scatterplot(ax=axs, x="DBH", y="TreeHeight", hue="Genus_spec", data=Ulmus_df)
axs.set_title("DBH vs. Tree Height", fontsize=20, color="#000000")
handles, labels = axs.get_legend_handles_labels()
axs.legend(handles=handles[1:], labels=labels[1:], title="Genus_species", title_fontsize=12) # Optional
axs.grid(True)
fig.patch.set_facecolor('#adb7c7')
plt.show(fig)

# %% [markdown]
# ## Graph 3

# %% [markdown]
# #### Create a boxplot of DBH for just the Ulmus genus differentiated by species (or, each species should have its own boxplot

# %%
#boxplot of DBH for Ulmus genus differenitated by species
plt.figure(figsize=(14, 13))
sns.boxplot(data=Ulmus_df, x='Species', y='DBH')
plt.title('Elm Species DBH')
plt.show()

# %% [markdown]
# ## Graph 4

# %% [markdown]
# #### Combine Graphs 1 and 3 into a single figure. Do not plot a legend for any of the graphs.

# %%
plt.figure(figsize=(10,4))
ax1 = plt.subplot(1,2,1)
sns.scatterplot(data=Ulmus_df, x='Species', ax=ax1)
ax2 = plt.subplot(1,2,2)
sns.boxplot(data=Ulmus_df, x='DBH', ax=ax2);

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
sns.scatterplot(data=Ulmus_df, x='DBH', ax=ax[0])
sns.boxplot(data=Ulmus_df, x='Species', ax=ax[1]);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[417], line 3
#       1 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
#       2 sns.scatterplot(data=Ulmus_df, x='DBH', ax=ax[0])
# ----> 3 sns.boxplot(data=Ulmus_df, x='Species', ax=ax[1]);
#
# File ~\miniconda3\envs\py4sa\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:

x = Ulmus_df['DBH'] 
y = Ulmus_df['TreeHeight']
plt.subplot(1, 2, 1)
plt.scatter(x,y)
#plot 2:
x = Ulmus_df['DBH']
y = Ulmus_df['Species']
a = Ulmus_df.loc[(Ulmus_df['Genus_spec']=='Ulmus pumila')]
plt.subplot(1, 2, 2)
plt.boxplot(a['DBH'],Ulmus_df['DBH'])
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[440], line 15
#      13 plt.subplot(1, 2, 2)
#      14 fuck=[a,x]
# ---> 15 plt.boxplot(fuck)
#      16 plt.show
#
# File ~\miniconda3\envs\py4sa\lib\site-packages\matplotlib\pyplot.py:2419, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2409 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2410 def boxplot(
#    2411         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2417         whiskerprops=None, manage_ticks=True, autorange=False,
#    2418         zorder=None, capwidths=None, *, data=None):
# -> 2419     return gca().boxplot(
# ...
